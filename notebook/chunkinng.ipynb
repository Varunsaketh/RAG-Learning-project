# %% [markdown]
# ### creating the chunnking functions

# %%
from langchain_text_splitters import SpacyTextSplitter
from langchain_text_splitters import NLTKTextSplitter
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_text_splitters import CharacterTextSplitter

# %% [markdown]
# we will be comparing some of the good text splitters refference from langchain community page
# https://reference.langchain.com/python/langchain-text-splitters

# %%
RCsplit = RecursiveCharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap = 50,
    length_function = len
)
csplit = CharacterTextSplitter(
    chunk_size = 500,
    chunk_overlap = 50,
    length_function = len
)
nltk_split = NLTKTextSplitter(
    chunk_size = 500,
    chunk_overlap = 50,
    length_function = len
)

# %% [markdown]
# for this spacyTextSplitter i have gone through lot of shit => installing spacy package and en_core_web_sm clearly mentioned in thier reference page https://reference.langchain.com/python/langchain-text-splitters/spacy/SpacyTextSplitter

# %%
spsplit = SpacyTextSplitter(
    chunk_size = 500,
    chunk_overlap = 50,
    length_function = len
)

# %%
import os
print(os.getcwd())
# Out:
# d:\vs codes\raglearning\notebook

# %%
from document_loader import textdoc1
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from Documentloader import textdoc1
#
# ModuleNotFoundError: No module named 'Documentloader'

# %%
rc_chuncks = RCsplit.split_documents(textdoc1)
